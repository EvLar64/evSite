# %%
import nltk
import matplotlib.pyplot as plt
from nltk import pos_tag
from nltk import FreqDist
from nltk.tokenize import word_tokenize
from nltk.text import Text
import numpy as np

# JOHN HUGHES PROJECT WORD DATA W/ PYTHON (notebook edition) - EL

# Takes in each screenplay text file
with open("ferris.txt",'r') as file:
    ferris=file.read()
with open("sixteen.txt",'r') as file:
    sixteen=file.read()
with open("breakfast.txt",'r') as file:
    breakfast=file.read()

# tokenizes and creates a text object with each script
ferris1 = word_tokenize(ferris)
text_ferris1 = Text(ferris1)
sixteen1 = word_tokenize(sixteen)
text_sixteen1 = Text(sixteen1)
breakfast1 = word_tokenize(breakfast)
text_breakfast1 = Text(breakfast1)

# frequency distributions made for each script
fdist_ferris = FreqDist(text_ferris1)
fdist_sixteen = FreqDist(text_sixteen1)
fdist_breakfast = FreqDist(text_breakfast1)

# concordance for a different word within each of the scripts
print()
print("Concordance of the word 'school' within the script for Ferris Bueller:")
text_ferris1.concordance("school")
print()
print("Concordance of the word 'birthday' within the script for Sixteen Candles:")
text_sixteen1.concordance("birthday")
print()
print("Concordance of the word 'detention' within the script for Breakfast Club:")
text_breakfast1.concordance("detention")
print()

# displays the 10 most common verbs in all three
print("10 most common verbs in Ferris Bueller:")
tagged_ferris = pos_tag(ferris1)
ferrisverbs = [word for word, tag in tagged_ferris if tag.startswith('VB')]
ferris_verbs = FreqDist(ferrisverbs)
ferris_common_verbs = ferris_verbs.most_common(10)
print(ferris_common_verbs)
print()

print("10 most common verbs in Sixteen Candles:")
tagged_sixteen = pos_tag(sixteen1)
sixteenverbs = [word for word, tag in tagged_sixteen if tag.startswith('VB')]
sixteen_verbs = FreqDist(sixteenverbs)
sixteen_common_verbs = sixteen_verbs.most_common(10)
print(sixteen_common_verbs)
print()

print("10 most common verbs in Breakfast Club:")
tagged_breakfast = pos_tag(breakfast1)
breakfastverbs = [word for word, tag in tagged_breakfast if tag.startswith('VB')]
breakfast_verbs = FreqDist(breakfastverbs)
breakfast_common_verbs = breakfast_verbs.most_common(10)
print(breakfast_common_verbs)
print()

# lexical richness as defined
# also rounding each number to three significant digits using f strings
print("Lexical Richness = Unique Words / Total Words")
print("Richness of Ferris Bueller:")
print(f"{(len(set(ferris1)) / len(ferris1)):.3f}")
print("Richness of Sixteen Candles:")
print(f"{(len(set(sixteen1)) / len(sixteen1)):.3f}")
print("Richness of Breakfast Club:")
print(f"{(len(set(breakfast1)) / len(breakfast1)):.3f}")

# makes specific words to find EXT. and INT. location frequency specifically,
# then counts them in Ferris Bueller
ferrisEXT = 'EXT.'
ferrisINT = 'INT.'
int_count = ferris.count(ferrisINT)
ext_count = ferris.count(ferrisEXT)

# prints the data before creating and outputting a pie chart
# comparing the frequencies of each type of location in the movie
print()
print(f"There are {int_count} '{ferrisINT}' locations in Ferris Bueller.")
print(f"There are {ext_count} '{ferrisEXT}' locations in Ferris Bueller.")
print()
plt.figure(1)
plt.title('Interior vs. Exterior Locations in Ferris Bueller')
y = np.array([int_count, ext_count])
loclabels = ["Interior Locations", "Exterior Locations"]
plt.pie(y, labels = loclabels)

# makes a set of strings as names from breakfast club (the most common ones)
# counts the mentions of each name in the screenplay and also plots this data
# on a bar graph
breakfast_characters = ['Allison', 'Andrew', 'Vernon', 'Bender', 'Brian', 'Claire']
name_counts = {name: breakfast1.count(name) for name in breakfast_characters}
plt.figure(2)
plt.bar(name_counts.keys(), name_counts.values())
plt.xlabel('Characters')
plt.ylabel('Screenplay Mentions')
plt.title('Frequency of Main Character Mentions in Breakfast Club')
plt.show()
# Out:
# Concordance of the word 'school' within the script for Ferris Bueller:
# Displaying 25 of 62 matches:
# HE MORNING . KIDS GETTING READY FOR SCHOOL . CLOCK RADIOS . KITCHEN APPLIANCES
# OOM . AN AURAL TOUR OF A HOUSE ON A SCHOOL MORNING . BEGINING IN THE KITCHEN A
# life ... JOYCE You 're not going to school like this . ( to Tom ) Maybe I shou
#  into the room . She 's dressed for school . She 's cute and stuck-up . A majo
# noyed ) Thank you , Jeanie . Get to school . JEANIE ( angry , defeated ) You '
# my eyes , you guys 'd make me go to school . It 's so unfair . FERRIS Please d
# or 's office and that 's worse than school . He flips on his stereo and fills
# id and childish but then so if high school . Right ? He equalizes the sound a
# ow can I be expected to handle high school ? He bends down OUT OF FRAME as he
# or him . He 's eighteen . Gone from school . Gone from life . His legacy is a
#  o'clock , when everybody 's out of school , you 're going to wish you 'd gone
# ou 're going to wish you 'd gone to school so you could be out having fun . He
#  over the counter remedies . A high school boy , CAMERON FRYE , is laying in b
# at he 'd owe taxes on it . 27 INT . SCHOOL . HALLWAY 27 We hear roll call as C
# tely forgot to call . 48 EXT . HIGH SCHOOL 48 A modern , suburban high school
#  SCHOOL 48 A modern , suburban high school . MAN 'S VOICE Are you aware that y
# e you aware that your son is not in school today ? 49 INT . SCHOOL . HALLWAY 4
# n is not in school today ? 49 INT . SCHOOL . HALLWAY 49 It 's a passing period
# mpletely slipped my mind . 50 INT . SCHOOL . DEAN 'S OUTER OFFICE 50 A SECRETA
# and fall back on the bed . 56 INT . SCHOOL . HALLWAY 56 Jeanie is at her locke
# ach ? It feels like that . 58 INT . SCHOOL . HALLWAY 58 A FRESHMAN BOY is on t
# ah . He 's getting me out of summer school . BOY Anyway , I appreciate you let
# es n't die . I ca n't handle summer school . The boy snatches a passing GIRL .
#  . The classroom door opens and the school NURSE walks in . For a moment , the
# 'll turn over your daughter . It 's school policy . Was this your mother ? Roo
#
# Concordance of the word 'birthday' within the script for Sixteen Candles:
# Displaying 25 of 27 matches:
# ly have n't come down to me 'Happy Birthday ' . at school . pissed that I let
# eed four inches of bod and a great birthday . DISSOLVE TO INT . HOUSE - SECOND
# he smiles , waiting for a `` happy birthday '' from him . SAM ( bright , cheer
#  hurry . And that 's it . No happy birthday . Sam is stunned . She watches him
#  Sam smiles and nods , expecting a birthday greeting from Ginny . GINNY The fi
# cally ) Thank you . Yes , it is my birthday . How nice of you to remember . IN
# renda . Again , she 's expecting a birthday greeting . BRENDA ( to Sam ) You m
# her one last chance to mention her birthday . BRENDA Do n't give me that pouty
# ieve this . They fucking forgot my birthday . Theme music comes up . EXT . HIG
#  today . If she ca n't remember my birthday , I ca n't expect her to remember
# ANDY I hope you get a car for your birthday . And a driver 's license . SAM Le
# . Sam drops a major hint about her birthday . SAM It 's a nice day is n't it ?
# at they , too , have forgotten her birthday . SAM I 'm going to set myself up
# ish . SAM It 's been a real shitty birthday for me . No offense , but I do n't
# d n't get shit . Not even a 'happy birthday ' . My whole family blew it off .
#  I 'd freak if my family forgot my birthday . Sam stretches out on the hood .
#  It 's a brand new year . It 's my birthday . I 'm sixteen . Everything should
# ch . JIM Oh , Jesus ! It 's Sam 's birthday . EXT . JAKE 'S HOUSE The few cars
# real jerk , honey . We forgot your birthday . Sam is pleased that he remembere
# Everything , everything . JIM Your birthday ? SAM No . CONTINUED 85 CONTINUED
# o do me a favor . Wish Sam a happy birthday . Ginny looks at Brenda like she '
# eetheart , I 'm sorry . About your birthday . We all are . Daddy said he talke
# he means . BRENDA I mean about her birthday . It was yesterday . We forgot . S
#  know she 's still upset about her birthday . MIKE We dumped on her royally ,
# the center of the pool . CLOSEUP - BIRTHDAY CAKE A birthday cake with sixteen
#
# Concordance of the word 'detention' within the script for Breakfast Club:
# Displaying 3 of 3 matches:
# d to sacrifice a whole Saturday in detention for whatever it was that we did wr
# e 's been a mistake . I know it 's detention , but ... um ... I do n't think I
# d to sacrifice a whole Saturday in detention for whatever it was we did wrong .
#
# 10 most common verbs in Ferris Bueller:
# [("'s", 376), ('is', 218), ("'m", 116), ('do', 94), ('have', 91), ('are', 91), ('was', 83), ("'re", 79), ('be', 69), ('looks', 59)]
#
# 10 most common verbs in Sixteen Candles:
# [("'s", 306), ('is', 173), ("'m", 94), ('are', 91), ('do', 85), ('looks', 77), ('have', 75), ("'re", 72), ('know', 63), ('be', 47)]
#
# 10 most common verbs in Breakfast Club:
# [('do', 162), ("'s", 144), ('is', 114), ("'re", 88), ('know', 79), ('see', 76), ('are', 69), ("'m", 68), ('be', 57), ('think', 52)]
#
# Lexical Richness = Unique Words / Total Words
# Richness of Ferris Bueller:
# 0.148
# Richness of Sixteen Candles:
# 0.143
# Richness of Breakfast Club:
# 0.130
#
# There are 159 'INT.' locations in Ferris Bueller.
# There are 102 'EXT.' locations in Ferris Bueller.
